# %%
import pandas as pd

# %%
df = pd.read_csv('features_primary.csv')
df.head(5)
# Out:
#         file cell_key  cycle_index  n_points  duration_s  voltage_start  \
# 0  B0005.mat    B0005            0       789    7597.875       3.873017
# 1  B0005.mat    B0005            1       197    3690.234       4.191492
# 2  B0005.mat    B0005            2       940   10516.000       3.325055
# 3  B0005.mat    B0005            3       196    3672.344       4.189773
# 4  B0005.mat    B0005            4       937   10484.547       3.352604
#
#    voltage_end  voltage_delta  voltage_slope_V_per_s  voltage_std  ...  \
# 0     4.191078       0.318060               0.000009     0.045765  ...
# 1     3.277170      -0.914322              -0.000206     0.235957  ...
# 2     4.189062       0.864007               0.000045     0.177380  ...
# 3     3.300245      -0.889528              -0.000205     0.234765  ...
# 4     4.187398       0.834795               0.000045     0.175287  ...
#
#    temp_start   temp_end  temp_change  energy_proxy_VAs  capacity  \
# ...

# %%
# Select the first N rows (e.g., 5) and columns you want
subset = df.head(5)  # you can also add .copy() if needed

# Save as a tab-delimited text file
subset.to_csv("battery_sample.tsv", sep='\t', index=False)

print("Tab-delimited file saved as 'battery_sample.tsv'.")
print("Open it, copy all, and paste into Google Docs — columns will align nicely.")
# Out:
# Tab-delimited file saved as 'battery_sample.tsv'.
# Open it, copy all, and paste into Google Docs — columns will align nicely.

# %%
df1 = df.head(5)

# %%
df1.to_csv("features_primary_data.csv", index=False)

# %%
data = pd.read_csv('features_primary_data.csv')
# Out:
#         file cell_key  cycle_index  n_points  duration_s  voltage_start  \
# 0  B0005.mat    B0005            0       789    7597.875       3.873017
# 1  B0005.mat    B0005            1       197    3690.234       4.191492
# 2  B0005.mat    B0005            2       940   10516.000       3.325055
# 3  B0005.mat    B0005            3       196    3672.344       4.189773
# 4  B0005.mat    B0005            4       937   10484.547       3.352604
#
#    voltage_end  voltage_delta  voltage_slope_V_per_s  voltage_std  ...  \
# 0     4.191078       0.318060               0.000009     0.045765  ...
# 1     3.277170      -0.914322              -0.000206     0.235957  ...
# 2     4.189062       0.864007               0.000045     0.177380  ...
# 3     3.300245      -0.889528              -0.000205     0.234765  ...
# 4     4.187398       0.834795               0.000045     0.175287  ...
#
#    temp_start   temp_end  temp_change  energy_proxy_VAs  capacity  \
# ...
